# %%
# import modules
import pandas as pd

# read in the vine_table.csv file as a dataframe
vine_table_df = pd.read_csv('vine_table.csv')
vine_table_df.head()
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0   RY01SAV7HZ8QO            4              0            0    N
# 1  R1XX8SDGJ4MZ4L            5              0            0    N
# 2  R149Q3B5L33NN5            5              0            0    N
# 3  R2ZVD69Z6KPJ4O            1              0            2    N
# 4  R1DIKG2G33ZLNP            4              0            0    N
#
#   verified_purchase
# 0                 Y
# 1                 N
# 2                 Y
# 3                 Y
# 4                 Y

# %%
# The data is filtered to create a DataFrame or table where there are 20 or more total votes
vine_table_filtered1 = vine_table_df[vine_table_df['total_votes'] >= 20]
vine_table_filtered1.head()
# Out:
#           review_id  star_rating  helpful_votes  total_votes vine  \
# 36   R1VCSDR38XTALJ            1             33           40    N
# 189  R1KMC6B2JRCZ3D            3             42           47    N
# 190  R1LV778IDGRJQ6            1              4           23    N
# 222   RBZE8H6SHVYWW            3             77          110    N
# 368  R2LBEAGVJA7HK1            3              5           48    N
#
#     verified_purchase
# 36                  N
# 189                 N
# 190                 Y
# 222                 N
# 368                 N

# %%
# The data is filtered to create a DataFrame or table where the percentage of helpful_votes is equal to or greater than 50%vine_table_filtered2 = vine_table_filtered1[(vine_table_filtered1['helpful_votes'] / vine_table_filtered1['total_votes']) >= 0.5]
vine_table_filtered2.head()
# Out:
#           review_id  star_rating  helpful_votes  total_votes vine  \
# 36   R1VCSDR38XTALJ            1             33           40    N
# 189  R1KMC6B2JRCZ3D            3             42           47    N
# 222   RBZE8H6SHVYWW            3             77          110    N
# 420  R3UN4H3BW9YTQA            5            358          388    N
# 429   R2YKRQ8R3B2Q3            5             30           35    N
#
#     verified_purchase
# 36                  N
# 189                 N
# 222                 N
# 420                 Y
# 429                 N

# %%
# The data is filtered to create a DataFrame or table where there is a Vine review
vine_table_paid = vine_table_filtered2[vine_table_filtered2['vine'] == 'Y']
vine_table_paid.head()
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 2359  R3LLICBKRHLRJC            4             17           22    Y
# 4451   RUD135S06DEVE            5             41           51    Y
# 5075  R2WG8UL4SGDPDH            4             23           25    Y
# 5083  R158AOKOA28WS2            4             18           28    Y
# 5223   RGWV3QLJQXU9X            5            332          380    Y
#
#      verified_purchase
# 2359                 N
# 4451                 N
# 5075                 N
# 5083                 N
# 5223                 N

# %%
# The data is filtered to create a DataFrame or table where there isn’t a Vine review
vine_table_unpaid = vine_table_filtered2[vine_table_filtered2['vine'] == 'N']
vine_table_unpaid.head()
# Out:
#           review_id  star_rating  helpful_votes  total_votes vine  \
# 36   R1VCSDR38XTALJ            1             33           40    N
# 189  R1KMC6B2JRCZ3D            3             42           47    N
# 222   RBZE8H6SHVYWW            3             77          110    N
# 420  R3UN4H3BW9YTQA            5            358          388    N
# 429   R2YKRQ8R3B2Q3            5             30           35    N
#
#     verified_purchase
# 36                  N
# 189                 N
# 222                 N
# 420                 Y
# 429                 N

# %%
# Total number of reviews for paid reviews
total_reviews_paid = vine_table_vine['review_id'].count()
# Total number of reviews for unpaid reviews
total_reviews_unpaid = vine_table_unpaid['review_id'].count()

# Number of 5-star reviews for paid reviews
five_star_reviews_paid = vine_table_vine[vine_table_vine['star_rating'] == 5]['review_id'].count()
# Number of 5-star reviews for unpaid reviews
five_star_reviews_unpaid = vine_table_unpaid[vine_table_unpaid['star_rating'] == 5]['review_id'].count()

# Percentage of 5-star reviews for paid reviews
percent_five_star_paid = (five_star_reviews_paid / total_reviews_paid) * 100
# Percentage of 5-star reviews for unpaid reviews
percent_five_star_unpaid = (five_star_reviews_unpaid / total_reviews_unpaid) * 100

paid_vs_unpaid = {'': ['Paid Reviews', 'Unpaid Reviews'],
                  'Total Number of Reviews': [total_reviews_paid, total_reviews_unpaid],
                  'Number of 5-star Reviews': [five_star_reviews_paid, five_star_reviews_unpaid],
                  'Percentage of 5-Star Reviews': [percent_five_star_paid, percent_five_star_unpaid]}
paid_vs_unpaid_df = pd.DataFrame(paid_vs_unpaid, index=None)
paid_vs_unpaid_df.head()
# Out:
#                    Total Number of Reviews  Number of 5-star Reviews  \
# 0    Paid Reviews                      261                       106
# 1  Unpaid Reviews                    24040                     10899
#
#    Percentage of 5-Star Reviews
# 0                     40.613027
# 1                     45.336938
